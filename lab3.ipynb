# %% [markdown]
# <a href="https://colab.research.google.com/github/LenokSb/MMVSULAB1/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Лабораторная работа № 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import odeint
url = 'https://raw.githubusercontent.com/LenokSb/MMVSULAB1/main/Volgograd.csv'
df = pd.read_csv(url)
print(df)
Years = np.array(df['Years'])
Population = np.array(df['Population'])
def dydt(Years,Population):
  k = 0.0044
  return k*Years

plt.plot(Years, Population)
plt.grid(True)
plt.title('Численность населения г. Волгоград', fontsize=13)
# Out:
#     Years  Population
# 0    1786         627
# 1    1811        3800
# 2    1840        4400
# 3    1847        4805
# 4    1856        7200
# 5    1857        6478
# 6    1860        7027
# 7    1861        6700
# 8    1863        8400
# 9    1873       13932
# 10   1877       26510
# 11   1884       36308
# 12   1897       56500
# 13   1901       70000
# 14   1903       79759
# 15   1904       79312
# 16   1905       82020
# 17   1906       86756
# 18   1907       93084
# 19   1909      100000
# 20   1914      117675
# 21   1917      130000
# 22   1920       87300
# 23   1923      117200
# 24   1925      145400
# 25   1926      153502
# 26   1927      171200
# 27   1928      179700
# 28   1929      188200
# 29   1930      217000
# 30   1931      304097
# 31   1933      388000
# 32   1937      392088
# 33   1939      445312
# 34   1941      500000
# 35   1943       32181
# 36   1944      284800
# 37   1956      525000
# 38   1959      593844
# 39   1962      649000
# ...
