# %% [markdown]
# <a href="https://colab.research.google.com/github/LenokSb/MMVSULAB1/blob/main/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dxdt(x,t):
    k=0.5
    return k*x
t=np.linspace(0, 100 , 100)

solve_1=odeint(dxdt,y0=1,t=t)
solve_1=solve_1.flatten()

def euler(f, y0=1, h=0.01, N = 100):
    eul = np.arange(0,N+h,h)
    y = [y0]
    for i in range(len(eul)-1):
        y.append(y[i] + h*f(y[i],eul[i]))
    return y, eul
solve_2, eul = euler(dxdt)

plt.plot(eul, solve_2,  label = r"Метод Эйлера")
plt.plot(t, solve_1,  label=r"x'=kx")
plt.grid(True)
plt.legend()
plt.show()
